# %%
import matplotlib.pyplot as plt
import numpy as np

# Durations for each thread count
thread_counts = [1, 2, 4, 8]

durations = {
    1: [55, 55, 59, 63, 70, 85, 75, 78, 79, 79, 81, 81, 80, 79, 78, 80, 80, 79, 81, 79, 75, 73, 70, 69, 74, 71, 67, 61, 59, 59, 61, 61, 60, 59, 60, 61, 64, 65, 65, 66, 66, 68, 72, 72, 71, 69, 70, 69, 73, 71, 71, 68, 68, 67, 72, 70, 69, 66, 66, 65, 69, 67, 67, 64, 64, 64, 68, 68, 66, 65, 64, 66, 69, 68, 68, 66, 66, 66, 70, 69, 68, 66, 66, 67, 71, 69, 68, 68, 68, 66, 70, 69, 68, 65, 65, 64, 68, 67, 66, 64],
    2: [41, 39, 45, 49, 52, 47, 61, 50, 51, 65, 67, 51, 66, 51, 64, 63, 63, 64, 53, 52, 59, 56, 54, 46, 48, 45, 45, 41, 43, 41, 42, 44, 44, 44, 43, 43, 48, 44, 48, 50, 45, 45, 55, 47, 55, 54, 46, 54, 56, 46, 53, 52, 52, 43, 55, 54, 52, 50, 48, 49, 45, 51, 50, 50, 48, 45, 51, 43, 54, 49, 43, 51, 53, 51, 51, 45, 50, 43, 47, 47, 51, 50, 50, 47, 46, 47, 52, 51, 43, 49, 54, 51, 45, 44, 45, 48, 52, 50, 43, 44],
    4: [34, 33, 33, 36, 39, 41, 43, 45, 37, 46, 45, 47, 45, 43, 46, 46, 47, 46, 48, 43, 42, 40, 37, 38, 59, 40, 38, 34, 35, 33, 35, 34, 34, 34, 33, 35, 35, 36, 37, 36, 37, 37, 39, 39, 40, 34, 39, 34, 41, 40, 40, 39, 45, 42, 42, 39, 37, 36, 36, 36, 39, 39, 38, 37, 35, 34, 37, 38, 36, 35, 36, 38, 39, 37, 39, 35, 37, 39, 39, 39, 38, 38, 36, 36, 40, 38, 37, 35, 40, 34, 39, 38, 39, 37, 39, 36, 35, 37, 38, 44],
    8: [33, 34, 34, 37, 37, 35, 38, 35, 38, 40, 34, 39, 36, 37, 37, 37, 40, 39, 39, 38, 37, 35, 36, 35, 37, 35, 36, 35, 34, 34, 34, 34, 34, 34, 34, 34, 35, 34, 34, 34, 34, 35, 35, 35, 36, 35, 35, 34, 36, 36, 35, 34, 38, 35, 40, 45, 35, 36, 38, 33, 35, 35, 35, 36, 35, 34, 35, 36, 35, 37, 34, 36, 37, 34, 37, 36, 36, 35, 39, 36, 34, 38, 35, 33, 35, 35, 35, 34, 37, 34, 36, 35, 36, 34, 35, 35, 35, 35, 35, 35]
}

# Calculate Min, Max, and Avg durations for each thread count
min_durations = [min(durations[count]) for count in thread_counts]
max_durations = [max(durations[count]) for count in thread_counts]
avg_durations = [sum(durations[count]) / len(durations[count]) for count in thread_counts]

# Create separate subplots for Min, Max, Avg, and Combined durations per thread count
fig, axs = plt.subplots(1, 3, figsize=(20, 7))

# Plot Min durations for each thread count next to each other
for i, count in enumerate(thread_counts):
    axs[0].bar(i, min_durations[i], color='red')
axs[0].set_xticks(np.arange(len(thread_counts)))
axs[0].set_xticklabels(thread_counts)
axs[0].set_title('Min Duration Per Thread Count')
axs[0].set_xlabel('Thread Count')
axs[0].set_ylabel('Duration (ms)')
axs[0].set_ylim(0, 60)  # Set y-axis limit to 60

# Plot Max durations for each thread count next to each other
for i, count in enumerate(thread_counts):
    axs[1].bar(i, max_durations[i], color='blue')
axs[1].set_xticks(np.arange(len(thread_counts)))
axs[1].set_xticklabels(thread_counts)
axs[1].set_title('Max Duration Per Thread Count')
axs[1].set_xlabel('Thread Count')
axs[1].set_ylabel('Duration (ms)')
axs[1].set_ylim(0, 90)  # Set y-axis limit to 90

# Plot Avg durations for each thread count next to each other
for i, count in enumerate(thread_counts):
    axs[2].bar(i, avg_durations[i], color='green')
axs[2].set_xticks(np.arange(len(thread_counts)))
axs[2].set_xticklabels(thread_counts)
axs[2].set_title('Average Duration Per Thread Count')
axs[2].set_xlabel('Thread Count')
axs[2].set_ylabel('Duration (ms)')


plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Durations for each thread count
thread_counts = [1, 2, 4, 8]

durations = {
    1: [55, 55, 59, 63, 70, 85, 75, 78, 79, 79, 81, 81, 80, 79, 78, 80, 80, 79, 81, 79, 75, 73, 70, 69, 74, 71, 67, 61, 59, 59, 61, 61, 60, 59, 60, 61, 64, 65, 65, 66, 66, 68, 72, 72, 71, 69, 70, 69, 73, 71, 71, 68, 68, 67, 72, 70, 69, 66, 66, 65, 69, 67, 67, 64, 64, 64, 68, 68, 66, 65, 64, 66, 69, 68, 68, 66, 66, 66, 70, 69, 68, 66, 66, 67, 71, 69, 68, 68, 68, 66, 70, 69, 68, 65, 65, 64, 68, 67, 66, 64],
    2: [41, 39, 45, 49, 52, 47, 61, 50, 51, 65, 67, 51, 66, 51, 64, 63, 63, 64, 53, 52, 59, 56, 54, 46, 48, 45, 45, 41, 43, 41, 42, 44, 44, 44, 43, 43, 48, 44, 48, 50, 45, 45, 55, 47, 55, 54, 46, 54, 56, 46, 53, 52, 52, 43, 55, 54, 52, 50, 48, 49, 45, 51, 50, 50, 48, 45, 51, 43, 54, 49, 43, 51, 53, 51, 51, 45, 50, 43, 47, 47, 51, 50, 50, 47, 46, 47, 52, 51, 43, 49, 54, 51, 45, 44, 45, 48, 52, 50, 43, 44],
    4: [34, 33, 33, 36, 39, 41, 43, 45, 37, 46, 45, 47, 45, 43, 46, 46, 47, 46, 48, 43, 42, 40, 37, 38, 59, 40, 38, 34, 35, 33, 35, 34, 34, 34, 33, 35, 35, 36, 37, 36, 37, 37, 39, 39, 40, 34, 39, 34, 41, 40, 40, 39, 45, 42, 42, 39, 37, 36, 36, 36, 39, 39, 38, 37, 35, 34, 37, 38, 36, 35, 36, 38, 39, 37, 39, 35, 37, 39, 39, 39, 38, 38, 36, 36, 40, 38, 37, 35, 40, 34, 39, 38, 39, 37, 39, 36, 35, 37, 38, 44],
    8: [33, 34, 34, 37, 37, 35, 38, 35, 38, 40, 34, 39, 36, 37, 37, 37, 40, 39, 39, 38, 37, 35, 36, 35, 37, 35, 36, 35, 34, 34, 34, 34, 34, 34, 34, 34, 35, 34, 34, 34, 34, 35, 35, 35, 36, 35, 35, 34, 36, 36, 35, 34, 38, 35, 40, 45, 35, 36, 38, 33, 35, 35, 35, 36, 35, 34, 35, 36, 35, 37, 34, 36, 37, 34, 37, 36, 36, 35, 39, 36, 34, 38, 35, 33, 35, 35, 35, 34, 37, 34, 36, 35, 36, 34, 35, 35, 35, 35, 35, 35]
}

# Calculate Min, Max, and Avg durations for each thread count
min_durations = [min(durations[count]) for count in thread_counts]
max_durations = [max(durations[count]) for count in thread_counts]
avg_durations = [sum(durations[count]) / len(durations[count]) for count in thread_counts]

# Create a subplot for Min, Max, and Avg durations in one graph
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.2
index = np.arange(len(thread_counts))

# Plot Min durations
ax.bar(index - bar_width, min_durations, bar_width, color='red', label='Min Duration')

# Plot Max durations
ax.bar(index, max_durations, bar_width, color='blue', label='Max Duration')

# Plot Avg durations
ax.bar(index + bar_width, avg_durations, bar_width, color='green', label='Avg Duration')

ax.set_xlabel('Thread Count')
ax.set_ylabel('Duration (ms)')
ax.set_title('Min, Max, and Avg Durations Per Thread Count')
ax.set_xticks(index)
ax.set_xticklabels(thread_counts)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Durations for each thread count
thread_counts = [1, 2, 4, 8]

# Provided durations data
durations = {
    1: [55, 55, 59, 63, 70, 85, 75, 78, 79, 79, 81, 81, 80, 79, 78, 80, 80, 79, 81, 79, 75, 73, 70, 69, 74, 71, 67, 61, 59, 59, 61, 61, 60, 59, 60, 61, 64, 65, 65, 66, 66, 68, 72, 72, 71, 69, 70, 69, 73, 71, 71, 68, 68, 67, 72, 70, 69, 66, 66, 65, 69, 67, 67, 64, 64, 64, 68, 68, 66, 65, 64, 66, 69, 68, 68, 66, 66, 66, 70, 69, 68, 66, 66, 67, 71, 69, 68, 68, 68, 66, 70, 69, 68, 65, 65, 64, 68, 67, 66, 64],
    2: [41, 39, 45, 49, 52, 47, 61, 50, 51, 65, 67, 51, 66, 51, 64, 63, 63, 64, 53, 52, 59, 56, 54, 46, 48, 45, 45, 41, 43, 41, 42, 44, 44, 44, 43, 43, 48, 44, 48, 50, 45, 45, 55, 47, 55, 54, 46, 54, 56, 46, 53, 52, 52, 43, 55, 54, 52, 50, 48, 49, 45, 51, 50, 50, 48, 45, 51, 43, 54, 49, 43, 51, 53, 51, 51, 45, 50, 43, 47, 47, 51, 50, 50, 47, 46, 47, 52, 51, 43, 49, 54, 51, 45, 44, 45, 48, 52, 50, 43, 44],
    4: [34, 33, 33, 36, 39, 41, 43, 45, 37, 46, 45, 47, 45, 43, 46, 46, 47, 46, 48, 43, 42, 40, 37, 38, 59, 40, 38, 34, 35, 33, 35, 34, 34, 34, 33, 35, 35, 36, 37, 36, 37, 37, 39, 39, 40, 34, 39, 34, 41, 40, 40, 39, 45, 42, 42, 39, 37, 36, 36, 36, 39, 39, 38, 37, 35, 34, 37, 38, 36, 35, 36, 38, 39, 37, 39, 35, 37, 39, 39, 39, 38, 38, 36, 36, 40, 38, 37, 35, 40, 34, 39, 38, 39, 37, 39, 36, 35, 37, 38, 44],
    8: [33, 34, 34, 37, 37, 35, 38, 35, 38, 40, 34, 39, 36, 37, 37, 37, 40, 39, 39, 38, 37, 35, 36, 35, 37, 35, 36, 35, 34, 34, 34, 34, 34, 34, 34, 34, 35, 34, 34, 34, 34, 35, 35, 35, 36, 35, 35, 34, 36, 36, 35, 34, 38, 35, 40, 45, 35, 36, 38, 33, 35, 35, 35, 36, 35, 34, 35, 36, 35, 37, 34, 36, 37, 34, 37, 36, 36, 35, 39, 36, 34, 38, 35, 33, 35, 35, 35, 34, 37, 34, 36, 35, 36, 34, 35, 35, 35, 35, 35, 35]
}

# Calculate mean durations and standard deviations for each thread count
mean_durations = [np.mean(durations[count]) for count in thread_counts]
std_durations = [np.std(durations[count]) for count in thread_counts]

# Plotting the Error line plot
plt.figure(figsize=(10, 6))

plt.errorbar(thread_counts, mean_durations, yerr=std_durations, fmt='-o', color='skyblue', ecolor='orange', capsize=5)

plt.xlabel('Thread Count')
plt.ylabel('Duration (ms)')
plt.title('Wa-Tor Parallelization Benchmark - Error line plot')
plt.xticks(np.arange(1, 11, 1))
plt.yticks(np.arange(5, 81, 5))  # Set y-axis ticks from 5 to 80
plt.grid(axis='y')

plt.tight_layout()
plt.show()
